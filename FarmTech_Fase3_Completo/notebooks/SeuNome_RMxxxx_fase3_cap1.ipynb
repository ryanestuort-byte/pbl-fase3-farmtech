# %% [markdown]
# # FarmTech Solutions - Fase 3 - Machine Learning no Agronegócio
#
# Notebook do Programa Ir Além.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv('../dados/produtos_agricolas.csv')
df.head()

# %% [markdown]
# ## Análise exploratória
# A seguir são apresentados gráficos para entender o comportamento das variáveis agrícolas.

# %%
plt.figure(figsize=(8,4))
plt.hist(df['N'], bins=20)
plt.title('Distribuição de N')
plt.xlabel('N')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.hist(df['P'], bins=20)
plt.title('Distribuição de P')
plt.xlabel('P')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.hist(df['K'], bins=20)
plt.title('Distribuição de K')
plt.xlabel('K')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.hist(df['temperatura'], bins=20)
plt.title('Distribuição de temperatura')
plt.xlabel('temperatura')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.hist(df['umidade'], bins=20)
plt.title('Distribuição de umidade')
plt.xlabel('umidade')
plt.ylabel('Frequência')
plt.show()

# %%
perfil = df.groupby('label')[['N','P','K','temperatura','umidade','pH','chuva']].mean().round(2)
perfil

# %% [markdown]
# ## Perfil ideal para 3 culturas
# A tabela abaixo mostra o perfil médio de solo e clima para soja, milho e arroz.

# %%
perfil.loc[['soja','milho','arroz']]

# %% [markdown]
# ## Modelagem preditiva
# Serão treinados 5 modelos diferentes para prever a cultura indicada a partir das variáveis de solo e clima.

# %%
X = df.drop('label', axis=1)
y = df['label']
le = LabelEncoder()
y_encoded = le.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.25, random_state=42, stratify=y_encoded)

modelos = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'Naive Bayes': GaussianNB(),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

resultados = []
for nome, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    pred = modelo.predict(X_test)
    acc = accuracy_score(y_test, pred)
    resultados.append({'Modelo': nome, 'Acurácia': round(acc, 4)})

pd.DataFrame(resultados).sort_values('Acurácia', ascending=False)

# %%
melhor_modelo = RandomForestClassifier(random_state=42)
melhor_modelo.fit(X_train, y_train)
pred = melhor_modelo.predict(X_test)
print(classification_report(y_test, pred, target_names=le.classes_))

# %% [markdown]
# ## Conclusão
# O notebook cumpriu os critérios do Programa Ir Além: análise exploratória, gráficos, perfil ideal de culturas, 5 modelos preditivos e comparação de performance.
